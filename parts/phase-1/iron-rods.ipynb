# %% [markdown]
# # Iron Rods
#
# **Type:** Producer — stores output in dimensional depot
# **Blueprint:** `iron-rod` (60 Iron Ingots/min → 60 Iron Rods/min at 100%)
# **Supply:** 180.75 of 810 total Iron Ingots/min
# **Downstream:** Rotors pulls `available_for_rotors` from storage

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../..').resolve()))

from blueprints import BLUEPRINTS, Blueprint, Stage
from satisfactory import ITEMS

BP  = BLUEPRINTS
TOL = 0.5

# %% [markdown]
# ## Constants

# %%
# ── Supply ────────────────────────────────────────────────────────────────────
IRON_INGOTS = 180.75  # items/min

# ── Stash target ──────────────────────────────────────────────────────────────
STASH_RATE = 20.0   # Iron Rods/min accumulating in storage

# ── Blueprint placement ───────────────────────────────────────────────────────
ROD_COPIES      = 4
ROD_OUTPUT_EACH = 45.19  # Iron Rods/min — set this on each blueprint in-game

# %% [markdown]
# ## Derived rates and balance

# %%
rod_total  = ROD_COPIES * ROD_OUTPUT_EACH
rod_ingots = rod_total  * BP['iron-rod'].input_ratio('iron-ingot', 'iron-rod')

available_for_rotors = rod_total - STASH_RATE

assert abs(rod_ingots - IRON_INGOTS) < TOL, (
    f"Ingot balance: consuming {rod_ingots:.2f}/min, supplied {IRON_INGOTS:.2f}/min "
    f"(delta {rod_ingots - IRON_INGOTS:+.2f})"
)
assert available_for_rotors > 0

print(f"✓ Chain balanced")
print(f"  {IRON_INGOTS:.2f} Iron Ingots/min  →  {rod_total:.2f} Iron Rods/min")
print(f"  Stashing:              {STASH_RATE:.0f} Iron Rods/min")
print(f"  Available for Rotors:  {available_for_rotors:.2f} Iron Rods/min")
print()
for r in BP['iron-rod'].stage_rates('iron-rod', ROD_OUTPUT_EACH):
    name = ITEMS[r['item_key']].name
    print(f"  {r['machines']}× Constructor → {r['per_machine_rate']:.2f} {name}/min each")
# Out:
# ✓ Chain balanced
#   180.75 Iron Ingots/min  →  180.76 Iron Rods/min
#   Stashing:              20 Iron Rods/min
#   Available for Rotors:  160.76 Iron Rods/min
#
#   4× Constructor → 11.30 Iron Rod/min each
